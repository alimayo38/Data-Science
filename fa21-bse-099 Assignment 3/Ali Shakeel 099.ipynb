# %%
# 26-Nov-23
# CSC461 – Assignment3 – Machine Learning
# Ali Shakeel
# FA21-BSE-099
# ML Algorithms

# %%
# !pip install scikit-plot

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cfab32e-b892-40cb-a81e-206450a098b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cfab32e-b892-40cb-a81e-206450a098b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['gender-prediction (2).csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
class_counts = df['gender'].value_counts()
print(class_counts)

class_ratio = class_counts / len(df)

print("Class Ratio:")
print(class_ratio)
# Out:
# male      62
# female    48
# Name: gender, dtype: int64
# Class Ratio:
# male      0.563636
# female    0.436364
# Name: gender, dtype: float64

# %%
df.dtypes

# %%
# Question 2
#import libraries
from sklearn import preprocessing
#converting strings into numbers

cat_att = ["beard", "hair_length",	"scarf",	"eye_color", "gender"]
labels = preprocessing.LabelEncoder()
df["beard-t"] = labels.fit_transform(df.beard)
df["hair-len-t"] = labels.fit_transform(df.hair_length)
df["scarf-t"] = labels.fit_transform(df.scarf)
df["eye-color-t"] = labels.fit_transform(df.eye_color)
df["gender-t"] = labels.fit_transform(df.gender)
df.head()
# Out:
#    height  weight beard hair_length  shoe_size scarf eye_color  gender  \
# 0      71     176   yes       short         44    no     black    male
# 1      68     165    no        bald         41    no     black    male
# 2      62     132    no      medium         37   yes      blue  female
# 3      65     138    no        long         38    no      gray  female
# 4      70     197   yes      medium         43    no      gray    male
#
#    beard-t  hair-len-t  scarf-t  eye-color-t  gender-t
# 0        1           3        0            0         1
# 1        0           0        0            0         1
# 2        0           2        1            1         0
# 3        0           1        0            3         0
# 4        1           2        0            3         1

# %%
# Define input features and target output variable
drop_att = ["beard", "hair_length",	"scarf",	"eye_color", "gender","gender-t"]
X = df.drop(drop_att, axis=1)
y = df['gender-t']

df
# Out:
#      height  weight beard hair_length  shoe_size scarf eye_color  gender  \
# 0        71     176   yes       short         44    no     black    male
# 1        68     165    no        bald         41    no     black    male
# 2        62     132    no      medium         37   yes      blue  female
# 3        65     138    no        long         38    no      gray  female
# 4        70     197   yes      medium         43    no      gray    male
# ..      ...     ...   ...         ...        ...   ...       ...     ...
# 105      61     103    no        long         38    no     green  female
# 106      68     135    no        long         37   yes     green  female
# 107      66     140    no        long         36   yes      gray  female
# 108      66     132    no      medium         37    no     black  female
# 109      70     160    no        long         42    no     black    male
#
#      beard-t  hair-len-t  scarf-t  eye-color-t  gender-t
# ...

# %%
#make train/test split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 2)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Create a Logistic Regression model
logistic_reg = LogisticRegression()

# Train the model on the training set
logistic_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = logistic_reg.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.972972972972973
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.96      0.98        23
#
#     accuracy                           0.97        37
#    macro avg       0.97      0.98      0.97        37
# weighted avg       0.97      0.97      0.97        37
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn import metrics, model_selection

model_cm = metrics.confusion_matrix(y_test, y_pred)
print(model_cm)

#1 instance is classified incorrect
# Out:
# [[14  0]
#  [ 1 22]]

# %%
#Question 2 part 2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 2)
# Create a Logistic Regression model
logistic_reg = LogisticRegression()

# Train the model on the training set
logistic_reg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = logistic_reg.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print the results
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_rep)

model_cm = metrics.confusion_matrix(y_test, y_pred)
print(model_cm)

#0 instance is classified incorrect
# Out:
# Accuracy: 0.9090909090909091
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88         9
#            1       0.87      1.00      0.93        13
#
#     accuracy                           0.91        22
#    macro avg       0.93      0.89      0.90        22
# weighted avg       0.92      0.91      0.91        22
#
# [[ 7  2]
#  [ 0 13]]

# %%
#question 2 part 3

#Beard and scarf are the two powerful attributes

# %%
#question 2 part 4

drop_att = ["beard", "hair_length",	"scarf",	"eye_color", "gender","gender-t","beard-t","scarf-t"]
X = df.drop(drop_att, axis=1)
y = df['gender-t']

#accuracy decreased to 90%

# %%
# Question #3

import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, KFold, LeavePOut
from sklearn.metrics import f1_score
from sklearn import preprocessing


# Define the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Monte Carlo Cross-Validation
num_iterations = 10  # You can choose any number of iterations
f1_scores_monte_carlo = []

for _ in range(num_iterations):
    # Use random_state for reproducibility
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=np.random.randint(1, 100))

    rf_classifier.fit(X_train, y_train)
    y_pred = rf_classifier.predict(X_test)

    f1_scores_monte_carlo.append(f1_score(y_test, y_pred, average='weighted'))

# Calculate the mean F1 score for Monte Carlo Cross-Validation
mean_f1_monte_carlo = np.mean(f1_scores_monte_carlo)

# Leave P-Out Cross-Validation
p_value = 2
leave_p_out = LeavePOut(p=p_value)
f1_scores_leave_p_out = cross_val_score(rf_classifier, X, y, cv=leave_p_out, scoring='f1_weighted')

# Calculate the mean F1 score for Leave P-Out Cross-Validation
mean_f1_leave_p_out = np.mean(f1_scores_leave_p_out)

# Print the results
print("Mean F1 score for Monte Carlo Cross-Validation:", mean_f1_monte_carlo)
print("Mean F1 score for Leave P-Out Cross-Validation:", mean_f1_leave_p_out)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-7e2e4c7caa4c> in <cell line: 32>()
#      30 p_value = 2  # You can choose any value for P
#      31 leave_p_out = LeavePOut(p=p_value)
# ---> 32 f1_scores_leave_p_out = cross_val_score(rf_classifier, X, y, cv=leave_p_out, scoring='f1_weighted')
#      33
#      34 # Calculate the mean F1 score for Leave P-Out Cross-Validation
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# ...

# %%
gender_counts = df['gender'].value_counts()

print(gender_counts)
# Out:
# male      62
# female    48
# Name: gender, dtype: int64

# %%
#Question 4

import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn import preprocessing

gnb_classifier = GaussianNB()
gnb_classifier.fit(X_train, y_train)

# Define input features and target output variable
drop_att = ["beard", "hair_length",	"scarf",	"eye_color", "gender","gender-t"]
X = df.tail(10).drop(drop_att, axis=1)
y = df.tail(10)['gender-t']

df

# Make predictions
y_pred = gnb_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')

# Report the results
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.9393939393939394
# Precision: 0.9449035812672175
# Recall: 0.9393939393939394
